# %% [markdown]
# # For a given day, download and plot SMAP L2 and L3 fields in the Beaufort Sea
#
# Uses cloud datasets - currently written to run on a local machine (and download files to local) but could be easily adapted to run on the cloud
#
# k.drushka // March 2022

# %%
# imports
import os
import requests
import numpy as np
# import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt
from pathlib import Path
import glob as glob

# from datetime import datetime

# plotting packages
import cartopy
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.ticker as mticker



# cloud stuff - ignore for now for working locally
# import s3fs

# %%
# ----- INPUTS ------
# define date and domain of interest

start_date = "2021-09-01T00:00:00"
end_date = "2021-09-01T23:59:59" # one day 
end_date = "2021-09-02T23:59:59" # multiple days 
date_range = start_date + "/" + end_date
print(date_range)

# beaufort sea. Use -180:180 longitude convention
lonrange = [-160, -130]
latrange = [68, 80]
bounding_box = (f'{lonrange[0]},{latrange[0]},{lonrange[1]},{latrange[1]}') # make this a string

# local data folder
datadir = '/data1/sassie/satellite/'
# Out:
# 2021-09-01T00:00:00/2021-09-02T23:59:59

# %% [markdown]
# ### L3 SMAP SSS.
#
# Dataset notes:
# * SMAP data are now in the cloud - but we are working on our local machine, so download it anyway.
# * L3 JPL SMAP 8-day running mean is concept id C2208422957-POCLOUD (obtained from [earthdatasearch](https://search.earthdata.nasa.gov/search?q=SMAP%20Level%202B%20JPL&ff=Available%20from%20AWS%20Cloud))
# * JPL SMAP is better near sea ice, so use that rather than RSS SMAP.
# * note that JPL and RSS use different conventions for variable names (e.g., lat/lon/smap_sss vs latitude/longitude/sss), so code will have to be modified if RSS is to be use if both products are desired
#
#
# This code requires that the user's .netrc file includes a PO.DAAC tools password, which is accessed here: https://podaac-tools.jpl.nasa.gov/drive/ :
# ```
# machine podaac-tools.jpl.nasa.gov \
# login USERNAME\
# password YOUR_PW
# ```

# %%
# --- DATASET INFO ---
# SMAP JPL L3 V5.0
concept_id = 'C2208422957-POCLOUD' 

# base URL for NASA earthdata search: 
granule_url = 'https://cmr.earthdata.nasa.gov/search/granules'

# use "requests" to find the granules in our date range & domain 
response = requests.get(granule_url,
                       params={
                           'concept_id': concept_id,
                           'temporal': date_range,  
                           'bounding_box': bounding_box,
                           'page_size': 200,
                       },
                       headers={
                           'Accept': 'application/json'
                       }
                      )
print(response.headers['CMR-Hits'])  # number of granules identified
# Out:
# 10

# %%
granules
# Out:
# [{'boxes': ['-90 -180 90 180'],
#   'time_start': '2021-08-24T12:00:00.000Z',
#   'updated': '2022-02-11T20:49:52.633Z',
#   'dataset_id': 'JPL SMAP Level 3 CAP Sea Surface Salinity Standard Mapped Image 8-Day Running Mean V5.0 Validated Dataset',
#   'data_center': 'POCLOUD',
#   'title': 'SMAP_L3_SSS_20210828_8DAYS_V5.0',
#   'coordinate_system': 'CARTESIAN',
#   'day_night_flag': 'UNSPECIFIED',
#   'time_end': '2021-09-01T12:00:00.000Z',
#   'id': 'G2215658221-POCLOUD',
#   'original_format': 'UMM_JSON',
#   'granule_size': '10.870092391967773',
#   'browse_flag': False,
#   'collection_concept_id': 'C2208422957-POCLOUD',
#   'online_access_flag': True,
#   'links': [{'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'title': 'Download SMAP_L3_SSS_20210828_8DAYS_V5.0.nc',
#     'hreflang': 'en-US',
#     'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/SMAP_JPL_L3_SSS_CAP_8DAY-RUNNINGMEAN_V5/2021/236/SMAP_L3_SSS_20210828_8DAYS_V5.0.nc'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/s3#',
#     'title': 'This link provides direct download access via S3 to the granule',
#     'hreflang': 'en-US',
#     'href': 's3://podaac-ops-cumulus-protected/SMAP_JPL_L3_SSS_CAP_8DAY-RUNNINGMEAN_V5/2021/236/SMAP_L3_SSS_20210828_8DAYS_V5.0.nc'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'title': 'Download SMAP_L3_SSS_20210828_8DAYS_V5.0.nc.md5',
#     'hreflang': 'en-US',
#     'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/SMAP_JPL_L3_SSS_CAP_8DAY-RUNNINGMEAN_V5/2021/236/SMAP_L3_SSS_20210828_8DAYS_V5.0.nc.md5'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'title': 'This link provides direct download access via S3 to the granule',
#     'hreflang': 'en-US',
#     'href': 's3://podaac-ops-cumulus-public/SMAP_JPL_L3_SSS_CAP_8DAY-RUNNINGMEAN_V5/2021/236/SMAP_L3_SSS_20210828_8DAYS_V5.0.nc.md5'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'title': 'api endpoint to retrieve temporary credentials valid for same-region direct s3 access',
#     'hreflang': 'en-US',
#     'href': 'https://archive.podaac.earthdata.nasa.gov/s3credentials'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/service#',
#     'title': 'OPeNDAP request URL',
#     'hreflang': 'en-US',
#     'href': 'https://opendap.earthdata.nasa.gov/collections/C2208422957-POCLOUD/granules/SMAP_L3_SSS_20210828_8DAYS_V5.0'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://github.com/podaac/data-readers'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://podaac-tools.jpl.nasa.gov/drive/files/allData/smap/docs/%20JPL-CAP_V5/'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'http://podaac.jpl.nasa.gov/smap'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'http://smap.jpl.nasa.gov/'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://podaac-tools.jpl.nasa.gov/drive/files/allData/smap/docs/%20JPL-CAP_V5/SMAP-SSS_JPL_V5.0_Documentation.pdf'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://podaac-tools.jpl.nasa.gov/drive/files/allData/smap/README.KnownIssues.txt'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://podaac.jpl.nasa.gov/CitingPODAAC'},
#    {'inherited': True,
#     'length': '0.0MB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'https://cmr.earthdata.nasa.gov/virtual-directory/collections/C2208422957-POCLOUD'},
#    {'inherited': True,
#     'length': '0.0MB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'https://search.earthdata.nasa.gov/search/granules?p=C2208422957-POCLOUD'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'hreflang': 'en-US',
#     'href': 'https://github.com/podaac/data-subscriber'}]},
#  {'boxes': ['-90 -180 90 180'],
#   'time_start': '2021-08-25T12:00:00.000Z',
#   'updated': '2022-02-11T20:49:48.380Z',
#   'dataset_id': 'JPL SMAP Level 3 CAP Sea Surface Salinity Standard Mapped Image 8-Day Running Mean V5.0 Validated Dataset',
#   'data_center': 'POCLOUD',
#   'title': 'SMAP_L3_SSS_20210829_8DAYS_V5.0',
#   'coordinate_system': 'CARTESIAN',
#   'day_night_flag': 'UNSPECIFIED',
#   'time_end': '2021-09-02T12:00:00.000Z',
#   'id': 'G2215658192-POCLOUD',
#   'original_format': 'UMM_JSON',
#   'granule_size': '6.4849853515625E-5',
#   'browse_flag': False,
#   'collection_concept_id': 'C2208422957-POCLOUD',
#   'online_access_flag': True,
#   'links': [{'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'title': 'Download SMAP_L3_SSS_20210829_8DAYS_V5.0.nc.md5',
#     'hreflang': 'en-US',
#     'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/SMAP_JPL_L3_SSS_CAP_8DAY-RUNNINGMEAN_V5/2021/237/SMAP_L3_SSS_20210829_8DAYS_V5.0.nc.md5'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'title': 'This link provides direct download access via S3 to the granule',
#     'hreflang': 'en-US',
#     'href': 's3://podaac-ops-cumulus-public/SMAP_JPL_L3_SSS_CAP_8DAY-RUNNINGMEAN_V5/2021/237/SMAP_L3_SSS_20210829_8DAYS_V5.0.nc.md5'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'title': 'Download SMAP_L3_SSS_20210829_8DAYS_V5.0.nc',
#     'hreflang': 'en-US',
#     'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/SMAP_JPL_L3_SSS_CAP_8DAY-RUNNINGMEAN_V5/2021/237/SMAP_L3_SSS_20210829_8DAYS_V5.0.nc'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/s3#',
#     'title': 'This link provides direct download access via S3 to the granule',
#     'hreflang': 'en-US',
#     'href': 's3://podaac-ops-cumulus-protected/SMAP_JPL_L3_SSS_CAP_8DAY-RUNNINGMEAN_V5/2021/237/SMAP_L3_SSS_20210829_8DAYS_V5.0.nc'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'title': 'api endpoint to retrieve temporary credentials valid for same-region direct s3 access',
#     'hreflang': 'en-US',
#     'href': 'https://archive.podaac.earthdata.nasa.gov/s3credentials'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/service#',
#     'title': 'OPeNDAP request URL',
#     'hreflang': 'en-US',
#     'href': 'https://opendap.earthdata.nasa.gov/collections/C2208422957-POCLOUD/granules/SMAP_L3_SSS_20210829_8DAYS_V5.0'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://github.com/podaac/data-readers'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://podaac-tools.jpl.nasa.gov/drive/files/allData/smap/docs/%20JPL-CAP_V5/'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'http://podaac.jpl.nasa.gov/smap'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'http://smap.jpl.nasa.gov/'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://podaac-tools.jpl.nasa.gov/drive/files/allData/smap/docs/%20JPL-CAP_V5/SMAP-SSS_JPL_V5.0_Documentation.pdf'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://podaac-tools.jpl.nasa.gov/drive/files/allData/smap/README.KnownIssues.txt'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://podaac.jpl.nasa.gov/CitingPODAAC'},
#    {'inherited': True,
#     'length': '0.0MB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'https://cmr.earthdata.nasa.gov/virtual-directory/collections/C2208422957-POCLOUD'},
#    {'inherited': True,
#     'length': '0.0MB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'https://search.earthdata.nasa.gov/search/granules?p=C2208422957-POCLOUD'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'hreflang': 'en-US',
#     'href': 'https://github.com/podaac/data-subscriber'}]},
#  {'boxes': ['-90 -180 90 180'],
#   'time_start': '2021-08-26T12:00:00.000Z',
#   'updated': '2022-02-11T20:49:34.798Z',
#   'dataset_id': 'JPL SMAP Level 3 CAP Sea Surface Salinity Standard Mapped Image 8-Day Running Mean V5.0 Validated Dataset',
#   'data_center': 'POCLOUD',
#   'title': 'SMAP_L3_SSS_20210830_8DAYS_V5.0',
#   'coordinate_system': 'CARTESIAN',
#   'day_night_flag': 'UNSPECIFIED',
#   'time_end': '2021-09-03T12:00:00.000Z',
#   'id': 'G2215658153-POCLOUD',
#   'original_format': 'UMM_JSON',
#   'granule_size': '10.85842514038086',
#   'browse_flag': False,
#   'collection_concept_id': 'C2208422957-POCLOUD',
#   'online_access_flag': True,
#   'links': [{'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'title': 'Download SMAP_L3_SSS_20210830_8DAYS_V5.0.nc.md5',
#     'hreflang': 'en-US',
#     'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/SMAP_JPL_L3_SSS_CAP_8DAY-RUNNINGMEAN_V5/2021/238/SMAP_L3_SSS_20210830_8DAYS_V5.0.nc.md5'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'title': 'This link provides direct download access via S3 to the granule',
#     'hreflang': 'en-US',
#     'href': 's3://podaac-ops-cumulus-public/SMAP_JPL_L3_SSS_CAP_8DAY-RUNNINGMEAN_V5/2021/238/SMAP_L3_SSS_20210830_8DAYS_V5.0.nc.md5'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'title': 'Download SMAP_L3_SSS_20210830_8DAYS_V5.0.nc',
#     'hreflang': 'en-US',
#     'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/SMAP_JPL_L3_SSS_CAP_8DAY-RUNNINGMEAN_V5/2021/238/SMAP_L3_SSS_20210830_8DAYS_V5.0.nc'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/s3#',
#     'title': 'This link provides direct download access via S3 to the granule',
#     'hreflang': 'en-US',
#     'href': 's3://podaac-ops-cumulus-protected/SMAP_JPL_L3_SSS_CAP_8DAY-RUNNINGMEAN_V5/2021/238/SMAP_L3_SSS_20210830_8DAYS_V5.0.nc'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'title': 'api endpoint to retrieve temporary credentials valid for same-region direct s3 access',
#     'hreflang': 'en-US',
#     'href': 'https://archive.podaac.earthdata.nasa.gov/s3credentials'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/service#',
#     'title': 'OPeNDAP request URL',
#     'hreflang': 'en-US',
#     'href': 'https://opendap.earthdata.nasa.gov/collections/C2208422957-POCLOUD/granules/SMAP_L3_SSS_20210830_8DAYS_V5.0'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://github.com/podaac/data-readers'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://podaac-tools.jpl.nasa.gov/drive/files/allData/smap/docs/%20JPL-CAP_V5/'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'http://podaac.jpl.nasa.gov/smap'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'http://smap.jpl.nasa.gov/'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://podaac-tools.jpl.nasa.gov/drive/files/allData/smap/docs/%20JPL-CAP_V5/SMAP-SSS_JPL_V5.0_Documentation.pdf'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://podaac-tools.jpl.nasa.gov/drive/files/allData/smap/README.KnownIssues.txt'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://podaac.jpl.nasa.gov/CitingPODAAC'},
#    {'inherited': True,
#     'length': '0.0MB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'https://cmr.earthdata.nasa.gov/virtual-directory/collections/C2208422957-POCLOUD'},
#    {'inherited': True,
#     'length': '0.0MB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'https://search.earthdata.nasa.gov/search/granules?p=C2208422957-POCLOUD'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'hreflang': 'en-US',
#     'href': 'https://github.com/podaac/data-subscriber'}]},
#  {'boxes': ['-90 -180 90 180'],
#   'time_start': '2021-08-27T12:00:00.000Z',
#   'updated': '2022-02-11T20:50:31.560Z',
#   'dataset_id': 'JPL SMAP Level 3 CAP Sea Surface Salinity Standard Mapped Image 8-Day Running Mean V5.0 Validated Dataset',
#   'data_center': 'POCLOUD',
#   'title': 'SMAP_L3_SSS_20210831_8DAYS_V5.0',
#   'coordinate_system': 'CARTESIAN',
#   'day_night_flag': 'UNSPECIFIED',
#   'time_end': '2021-09-04T12:00:00.000Z',
#   'id': 'G2215658484-POCLOUD',
#   'original_format': 'UMM_JSON',
#   'granule_size': '10.862590789794922',
#   'browse_flag': False,
#   'collection_concept_id': 'C2208422957-POCLOUD',
#   'online_access_flag': True,
#   'links': [{'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'title': 'Download SMAP_L3_SSS_20210831_8DAYS_V5.0.nc.md5',
#     'hreflang': 'en-US',
#     'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/SMAP_JPL_L3_SSS_CAP_8DAY-RUNNINGMEAN_V5/2021/239/SMAP_L3_SSS_20210831_8DAYS_V5.0.nc.md5'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'title': 'This link provides direct download access via S3 to the granule',
#     'hreflang': 'en-US',
#     'href': 's3://podaac-ops-cumulus-public/SMAP_JPL_L3_SSS_CAP_8DAY-RUNNINGMEAN_V5/2021/239/SMAP_L3_SSS_20210831_8DAYS_V5.0.nc.md5'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'title': 'Download SMAP_L3_SSS_20210831_8DAYS_V5.0.nc',
#     'hreflang': 'en-US',
#     'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/SMAP_JPL_L3_SSS_CAP_8DAY-RUNNINGMEAN_V5/2021/239/SMAP_L3_SSS_20210831_8DAYS_V5.0.nc'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/s3#',
#     'title': 'This link provides direct download access via S3 to the granule',
#     'hreflang': 'en-US',
#     'href': 's3://podaac-ops-cumulus-protected/SMAP_JPL_L3_SSS_CAP_8DAY-RUNNINGMEAN_V5/2021/239/SMAP_L3_SSS_20210831_8DAYS_V5.0.nc'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'title': 'api endpoint to retrieve temporary credentials valid for same-region direct s3 access',
#     'hreflang': 'en-US',
#     'href': 'https://archive.podaac.earthdata.nasa.gov/s3credentials'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/service#',
#     'title': 'OPeNDAP request URL',
#     'hreflang': 'en-US',
#     'href': 'https://opendap.earthdata.nasa.gov/collections/C2208422957-POCLOUD/granules/SMAP_L3_SSS_20210831_8DAYS_V5.0'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://github.com/podaac/data-readers'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://podaac-tools.jpl.nasa.gov/drive/files/allData/smap/docs/%20JPL-CAP_V5/'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'http://podaac.jpl.nasa.gov/smap'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'http://smap.jpl.nasa.gov/'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://podaac-tools.jpl.nasa.gov/drive/files/allData/smap/docs/%20JPL-CAP_V5/SMAP-SSS_JPL_V5.0_Documentation.pdf'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://podaac-tools.jpl.nasa.gov/drive/files/allData/smap/README.KnownIssues.txt'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://podaac.jpl.nasa.gov/CitingPODAAC'},
#    {'inherited': True,
#     'length': '0.0MB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'https://cmr.earthdata.nasa.gov/virtual-directory/collections/C2208422957-POCLOUD'},
#    {'inherited': True,
#     'length': '0.0MB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'https://search.earthdata.nasa.gov/search/granules?p=C2208422957-POCLOUD'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'hreflang': 'en-US',
#     'href': 'https://github.com/podaac/data-subscriber'}]},
#  {'boxes': ['-90 -180 90 180'],
#   'time_start': '2021-08-28T12:00:00.000Z',
#   'updated': '2022-02-11T20:49:52.590Z',
#   'dataset_id': 'JPL SMAP Level 3 CAP Sea Surface Salinity Standard Mapped Image 8-Day Running Mean V5.0 Validated Dataset',
#   'data_center': 'POCLOUD',
#   'title': 'SMAP_L3_SSS_20210901_8DAYS_V5.0',
#   'coordinate_system': 'CARTESIAN',
#   'day_night_flag': 'UNSPECIFIED',
#   'time_end': '2021-09-05T12:00:00.000Z',
#   'id': 'G2215658223-POCLOUD',
#   'original_format': 'UMM_JSON',
#   'granule_size': '10.847062110900879',
#   'browse_flag': False,
#   'collection_concept_id': 'C2208422957-POCLOUD',
#   'online_access_flag': True,
#   'links': [{'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'title': 'Download SMAP_L3_SSS_20210901_8DAYS_V5.0.nc',
#     'hreflang': 'en-US',
#     'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/SMAP_JPL_L3_SSS_CAP_8DAY-RUNNINGMEAN_V5/2021/240/SMAP_L3_SSS_20210901_8DAYS_V5.0.nc'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/s3#',
#     'title': 'This link provides direct download access via S3 to the granule',
#     'hreflang': 'en-US',
#     'href': 's3://podaac-ops-cumulus-protected/SMAP_JPL_L3_SSS_CAP_8DAY-RUNNINGMEAN_V5/2021/240/SMAP_L3_SSS_20210901_8DAYS_V5.0.nc'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'title': 'Download SMAP_L3_SSS_20210901_8DAYS_V5.0.nc.md5',
#     'hreflang': 'en-US',
#     'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/SMAP_JPL_L3_SSS_CAP_8DAY-RUNNINGMEAN_V5/2021/240/SMAP_L3_SSS_20210901_8DAYS_V5.0.nc.md5'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'title': 'This link provides direct download access via S3 to the granule',
#     'hreflang': 'en-US',
#     'href': 's3://podaac-ops-cumulus-public/SMAP_JPL_L3_SSS_CAP_8DAY-RUNNINGMEAN_V5/2021/240/SMAP_L3_SSS_20210901_8DAYS_V5.0.nc.md5'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'title': 'api endpoint to retrieve temporary credentials valid for same-region direct s3 access',
#     'hreflang': 'en-US',
#     'href': 'https://archive.podaac.earthdata.nasa.gov/s3credentials'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/service#',
#     'title': 'OPeNDAP request URL',
#     'hreflang': 'en-US',
#     'href': 'https://opendap.earthdata.nasa.gov/collections/C2208422957-POCLOUD/granules/SMAP_L3_SSS_20210901_8DAYS_V5.0'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://github.com/podaac/data-readers'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://podaac-tools.jpl.nasa.gov/drive/files/allData/smap/docs/%20JPL-CAP_V5/'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'http://podaac.jpl.nasa.gov/smap'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'http://smap.jpl.nasa.gov/'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://podaac-tools.jpl.nasa.gov/drive/files/allData/smap/docs/%20JPL-CAP_V5/SMAP-SSS_JPL_V5.0_Documentation.pdf'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://podaac-tools.jpl.nasa.gov/drive/files/allData/smap/README.KnownIssues.txt'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://podaac.jpl.nasa.gov/CitingPODAAC'},
#    {'inherited': True,
#     'length': '0.0MB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'https://cmr.earthdata.nasa.gov/virtual-directory/collections/C2208422957-POCLOUD'},
#    {'inherited': True,
#     'length': '0.0MB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'https://search.earthdata.nasa.gov/search/granules?p=C2208422957-POCLOUD'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'hreflang': 'en-US',
#     'href': 'https://github.com/podaac/data-subscriber'}]},
#  {'boxes': ['-90 -180 90 180'],
#   'time_start': '2021-08-29T12:00:00.000Z',
#   'updated': '2022-02-11T20:49:43.499Z',
#   'dataset_id': 'JPL SMAP Level 3 CAP Sea Surface Salinity Standard Mapped Image 8-Day Running Mean V5.0 Validated Dataset',
#   'data_center': 'POCLOUD',
#   'title': 'SMAP_L3_SSS_20210902_8DAYS_V5.0',
#   'coordinate_system': 'CARTESIAN',
#   'day_night_flag': 'UNSPECIFIED',
#   'time_end': '2021-09-06T12:00:00.000Z',
#   'id': 'G2215658182-POCLOUD',
#   'original_format': 'UMM_JSON',
#   'granule_size': '10.84847354888916',
#   'browse_flag': False,
#   'collection_concept_id': 'C2208422957-POCLOUD',
#   'online_access_flag': True,
#   'links': [{'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'title': 'Download SMAP_L3_SSS_20210902_8DAYS_V5.0.nc',
#     'hreflang': 'en-US',
#     'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/SMAP_JPL_L3_SSS_CAP_8DAY-RUNNINGMEAN_V5/2021/241/SMAP_L3_SSS_20210902_8DAYS_V5.0.nc'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/s3#',
#     'title': 'This link provides direct download access via S3 to the granule',
#     'hreflang': 'en-US',
#     'href': 's3://podaac-ops-cumulus-protected/SMAP_JPL_L3_SSS_CAP_8DAY-RUNNINGMEAN_V5/2021/241/SMAP_L3_SSS_20210902_8DAYS_V5.0.nc'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'title': 'Download SMAP_L3_SSS_20210902_8DAYS_V5.0.nc.md5',
#     'hreflang': 'en-US',
#     'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/SMAP_JPL_L3_SSS_CAP_8DAY-RUNNINGMEAN_V5/2021/241/SMAP_L3_SSS_20210902_8DAYS_V5.0.nc.md5'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'title': 'This link provides direct download access via S3 to the granule',
#     'hreflang': 'en-US',
#     'href': 's3://podaac-ops-cumulus-public/SMAP_JPL_L3_SSS_CAP_8DAY-RUNNINGMEAN_V5/2021/241/SMAP_L3_SSS_20210902_8DAYS_V5.0.nc.md5'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'title': 'api endpoint to retrieve temporary credentials valid for same-region direct s3 access',
#     'hreflang': 'en-US',
#     'href': 'https://archive.podaac.earthdata.nasa.gov/s3credentials'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/service#',
#     'title': 'OPeNDAP request URL',
#     'hreflang': 'en-US',
#     'href': 'https://opendap.earthdata.nasa.gov/collections/C2208422957-POCLOUD/granules/SMAP_L3_SSS_20210902_8DAYS_V5.0'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://github.com/podaac/data-readers'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://podaac-tools.jpl.nasa.gov/drive/files/allData/smap/docs/%20JPL-CAP_V5/'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'http://podaac.jpl.nasa.gov/smap'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'http://smap.jpl.nasa.gov/'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://podaac-tools.jpl.nasa.gov/drive/files/allData/smap/docs/%20JPL-CAP_V5/SMAP-SSS_JPL_V5.0_Documentation.pdf'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://podaac-tools.jpl.nasa.gov/drive/files/allData/smap/README.KnownIssues.txt'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://podaac.jpl.nasa.gov/CitingPODAAC'},
#    {'inherited': True,
#     'length': '0.0MB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'https://cmr.earthdata.nasa.gov/virtual-directory/collections/C2208422957-POCLOUD'},
#    {'inherited': True,
#     'length': '0.0MB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'https://search.earthdata.nasa.gov/search/granules?p=C2208422957-POCLOUD'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'hreflang': 'en-US',
#     'href': 'https://github.com/podaac/data-subscriber'}]},
#  {'boxes': ['-90 -180 90 180'],
#   'time_start': '2021-08-30T12:00:00.000Z',
#   'updated': '2022-02-11T20:49:41.819Z',
#   'dataset_id': 'JPL SMAP Level 3 CAP Sea Surface Salinity Standard Mapped Image 8-Day Running Mean V5.0 Validated Dataset',
#   'data_center': 'POCLOUD',
#   'title': 'SMAP_L3_SSS_20210903_8DAYS_V5.0',
#   'coordinate_system': 'CARTESIAN',
#   'day_night_flag': 'UNSPECIFIED',
#   'time_end': '2021-09-07T12:00:00.000Z',
#   'id': 'G2215658178-POCLOUD',
#   'original_format': 'UMM_JSON',
#   'granule_size': '6.4849853515625E-5',
#   'browse_flag': False,
#   'collection_concept_id': 'C2208422957-POCLOUD',
#   'online_access_flag': True,
#   'links': [{'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'title': 'Download SMAP_L3_SSS_20210903_8DAYS_V5.0.nc.md5',
#     'hreflang': 'en-US',
#     'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/SMAP_JPL_L3_SSS_CAP_8DAY-RUNNINGMEAN_V5/2021/242/SMAP_L3_SSS_20210903_8DAYS_V5.0.nc.md5'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'title': 'This link provides direct download access via S3 to the granule',
#     'hreflang': 'en-US',
#     'href': 's3://podaac-ops-cumulus-public/SMAP_JPL_L3_SSS_CAP_8DAY-RUNNINGMEAN_V5/2021/242/SMAP_L3_SSS_20210903_8DAYS_V5.0.nc.md5'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'title': 'Download SMAP_L3_SSS_20210903_8DAYS_V5.0.nc',
#     'hreflang': 'en-US',
#     'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/SMAP_JPL_L3_SSS_CAP_8DAY-RUNNINGMEAN_V5/2021/242/SMAP_L3_SSS_20210903_8DAYS_V5.0.nc'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/s3#',
#     'title': 'This link provides direct download access via S3 to the granule',
#     'hreflang': 'en-US',
#     'href': 's3://podaac-ops-cumulus-protected/SMAP_JPL_L3_SSS_CAP_8DAY-RUNNINGMEAN_V5/2021/242/SMAP_L3_SSS_20210903_8DAYS_V5.0.nc'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'title': 'api endpoint to retrieve temporary credentials valid for same-region direct s3 access',
#     'hreflang': 'en-US',
#     'href': 'https://archive.podaac.earthdata.nasa.gov/s3credentials'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/service#',
#     'title': 'OPeNDAP request URL',
#     'hreflang': 'en-US',
#     'href': 'https://opendap.earthdata.nasa.gov/collections/C2208422957-POCLOUD/granules/SMAP_L3_SSS_20210903_8DAYS_V5.0'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://github.com/podaac/data-readers'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://podaac-tools.jpl.nasa.gov/drive/files/allData/smap/docs/%20JPL-CAP_V5/'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'http://podaac.jpl.nasa.gov/smap'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'http://smap.jpl.nasa.gov/'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://podaac-tools.jpl.nasa.gov/drive/files/allData/smap/docs/%20JPL-CAP_V5/SMAP-SSS_JPL_V5.0_Documentation.pdf'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://podaac-tools.jpl.nasa.gov/drive/files/allData/smap/README.KnownIssues.txt'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://podaac.jpl.nasa.gov/CitingPODAAC'},
#    {'inherited': True,
#     'length': '0.0MB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'https://cmr.earthdata.nasa.gov/virtual-directory/collections/C2208422957-POCLOUD'},
#    {'inherited': True,
#     'length': '0.0MB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'https://search.earthdata.nasa.gov/search/granules?p=C2208422957-POCLOUD'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'hreflang': 'en-US',
#     'href': 'https://github.com/podaac/data-subscriber'}]},
#  {'boxes': ['-90 -180 90 180'],
#   'time_start': '2021-08-31T12:00:00.000Z',
#   'updated': '2022-02-11T20:49:38.585Z',
#   'dataset_id': 'JPL SMAP Level 3 CAP Sea Surface Salinity Standard Mapped Image 8-Day Running Mean V5.0 Validated Dataset',
#   'data_center': 'POCLOUD',
#   'title': 'SMAP_L3_SSS_20210904_8DAYS_V5.0',
#   'coordinate_system': 'CARTESIAN',
#   'day_night_flag': 'UNSPECIFIED',
#   'time_end': '2021-09-08T12:00:00.000Z',
#   'id': 'G2215658156-POCLOUD',
#   'original_format': 'UMM_JSON',
#   'granule_size': '10.84808349609375',
#   'browse_flag': False,
#   'collection_concept_id': 'C2208422957-POCLOUD',
#   'online_access_flag': True,
#   'links': [{'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'title': 'Download SMAP_L3_SSS_20210904_8DAYS_V5.0.nc',
#     'hreflang': 'en-US',
#     'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/SMAP_JPL_L3_SSS_CAP_8DAY-RUNNINGMEAN_V5/2021/243/SMAP_L3_SSS_20210904_8DAYS_V5.0.nc'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/s3#',
#     'title': 'This link provides direct download access via S3 to the granule',
#     'hreflang': 'en-US',
#     'href': 's3://podaac-ops-cumulus-protected/SMAP_JPL_L3_SSS_CAP_8DAY-RUNNINGMEAN_V5/2021/243/SMAP_L3_SSS_20210904_8DAYS_V5.0.nc'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'title': 'Download SMAP_L3_SSS_20210904_8DAYS_V5.0.nc.md5',
#     'hreflang': 'en-US',
#     'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/SMAP_JPL_L3_SSS_CAP_8DAY-RUNNINGMEAN_V5/2021/243/SMAP_L3_SSS_20210904_8DAYS_V5.0.nc.md5'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'title': 'This link provides direct download access via S3 to the granule',
#     'hreflang': 'en-US',
#     'href': 's3://podaac-ops-cumulus-public/SMAP_JPL_L3_SSS_CAP_8DAY-RUNNINGMEAN_V5/2021/243/SMAP_L3_SSS_20210904_8DAYS_V5.0.nc.md5'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'title': 'api endpoint to retrieve temporary credentials valid for same-region direct s3 access',
#     'hreflang': 'en-US',
#     'href': 'https://archive.podaac.earthdata.nasa.gov/s3credentials'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/service#',
#     'title': 'OPeNDAP request URL',
#     'hreflang': 'en-US',
#     'href': 'https://opendap.earthdata.nasa.gov/collections/C2208422957-POCLOUD/granules/SMAP_L3_SSS_20210904_8DAYS_V5.0'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://github.com/podaac/data-readers'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://podaac-tools.jpl.nasa.gov/drive/files/allData/smap/docs/%20JPL-CAP_V5/'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'http://podaac.jpl.nasa.gov/smap'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'http://smap.jpl.nasa.gov/'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://podaac-tools.jpl.nasa.gov/drive/files/allData/smap/docs/%20JPL-CAP_V5/SMAP-SSS_JPL_V5.0_Documentation.pdf'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://podaac-tools.jpl.nasa.gov/drive/files/allData/smap/README.KnownIssues.txt'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://podaac.jpl.nasa.gov/CitingPODAAC'},
#    {'inherited': True,
#     'length': '0.0MB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'https://cmr.earthdata.nasa.gov/virtual-directory/collections/C2208422957-POCLOUD'},
#    {'inherited': True,
#     'length': '0.0MB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'https://search.earthdata.nasa.gov/search/granules?p=C2208422957-POCLOUD'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'hreflang': 'en-US',
#     'href': 'https://github.com/podaac/data-subscriber'}]},
#  {'boxes': ['-90 -180 90 180'],
#   'time_start': '2021-09-01T12:00:00.000Z',
#   'updated': '2022-02-11T20:50:36.842Z',
#   'dataset_id': 'JPL SMAP Level 3 CAP Sea Surface Salinity Standard Mapped Image 8-Day Running Mean V5.0 Validated Dataset',
#   'data_center': 'POCLOUD',
#   'title': 'SMAP_L3_SSS_20210905_8DAYS_V5.0',
#   'coordinate_system': 'CARTESIAN',
#   'day_night_flag': 'UNSPECIFIED',
#   'time_end': '2021-09-09T12:00:00.000Z',
#   'id': 'G2215658536-POCLOUD',
#   'original_format': 'UMM_JSON',
#   'granule_size': '6.4849853515625E-5',
#   'browse_flag': False,
#   'collection_concept_id': 'C2208422957-POCLOUD',
#   'online_access_flag': True,
#   'links': [{'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'title': 'Download SMAP_L3_SSS_20210905_8DAYS_V5.0.nc',
#     'hreflang': 'en-US',
#     'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/SMAP_JPL_L3_SSS_CAP_8DAY-RUNNINGMEAN_V5/2021/244/SMAP_L3_SSS_20210905_8DAYS_V5.0.nc'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/s3#',
#     'title': 'This link provides direct download access via S3 to the granule',
#     'hreflang': 'en-US',
#     'href': 's3://podaac-ops-cumulus-protected/SMAP_JPL_L3_SSS_CAP_8DAY-RUNNINGMEAN_V5/2021/244/SMAP_L3_SSS_20210905_8DAYS_V5.0.nc'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'title': 'Download SMAP_L3_SSS_20210905_8DAYS_V5.0.nc.md5',
#     'hreflang': 'en-US',
#     'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/SMAP_JPL_L3_SSS_CAP_8DAY-RUNNINGMEAN_V5/2021/244/SMAP_L3_SSS_20210905_8DAYS_V5.0.nc.md5'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'title': 'This link provides direct download access via S3 to the granule',
#     'hreflang': 'en-US',
#     'href': 's3://podaac-ops-cumulus-public/SMAP_JPL_L3_SSS_CAP_8DAY-RUNNINGMEAN_V5/2021/244/SMAP_L3_SSS_20210905_8DAYS_V5.0.nc.md5'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'title': 'api endpoint to retrieve temporary credentials valid for same-region direct s3 access',
#     'hreflang': 'en-US',
#     'href': 'https://archive.podaac.earthdata.nasa.gov/s3credentials'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/service#',
#     'title': 'OPeNDAP request URL',
#     'hreflang': 'en-US',
#     'href': 'https://opendap.earthdata.nasa.gov/collections/C2208422957-POCLOUD/granules/SMAP_L3_SSS_20210905_8DAYS_V5.0'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://github.com/podaac/data-readers'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://podaac-tools.jpl.nasa.gov/drive/files/allData/smap/docs/%20JPL-CAP_V5/'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'http://podaac.jpl.nasa.gov/smap'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'http://smap.jpl.nasa.gov/'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://podaac-tools.jpl.nasa.gov/drive/files/allData/smap/docs/%20JPL-CAP_V5/SMAP-SSS_JPL_V5.0_Documentation.pdf'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://podaac-tools.jpl.nasa.gov/drive/files/allData/smap/README.KnownIssues.txt'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://podaac.jpl.nasa.gov/CitingPODAAC'},
#    {'inherited': True,
#     'length': '0.0MB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'https://cmr.earthdata.nasa.gov/virtual-directory/collections/C2208422957-POCLOUD'},
#    {'inherited': True,
#     'length': '0.0MB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'https://search.earthdata.nasa.gov/search/granules?p=C2208422957-POCLOUD'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'hreflang': 'en-US',
#     'href': 'https://github.com/podaac/data-subscriber'}]},
#  {'boxes': ['-90 -180 90 180'],
#   'time_start': '2021-09-02T12:00:00.000Z',
#   'updated': '2022-02-11T20:50:39.940Z',
#   'dataset_id': 'JPL SMAP Level 3 CAP Sea Surface Salinity Standard Mapped Image 8-Day Running Mean V5.0 Validated Dataset',
#   'data_center': 'POCLOUD',
#   'title': 'SMAP_L3_SSS_20210906_8DAYS_V5.0',
#   'coordinate_system': 'CARTESIAN',
#   'day_night_flag': 'UNSPECIFIED',
#   'time_end': '2021-09-10T12:00:00.000Z',
#   'id': 'G2215658561-POCLOUD',
#   'original_format': 'UMM_JSON',
#   'granule_size': '10.858319282531738',
#   'browse_flag': False,
#   'collection_concept_id': 'C2208422957-POCLOUD',
#   'online_access_flag': True,
#   'links': [{'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'title': 'Download SMAP_L3_SSS_20210906_8DAYS_V5.0.nc.md5',
#     'hreflang': 'en-US',
#     'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/SMAP_JPL_L3_SSS_CAP_8DAY-RUNNINGMEAN_V5/2021/245/SMAP_L3_SSS_20210906_8DAYS_V5.0.nc.md5'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'title': 'This link provides direct download access via S3 to the granule',
#     'hreflang': 'en-US',
#     'href': 's3://podaac-ops-cumulus-public/SMAP_JPL_L3_SSS_CAP_8DAY-RUNNINGMEAN_V5/2021/245/SMAP_L3_SSS_20210906_8DAYS_V5.0.nc.md5'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'title': 'Download SMAP_L3_SSS_20210906_8DAYS_V5.0.nc',
#     'hreflang': 'en-US',
#     'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/SMAP_JPL_L3_SSS_CAP_8DAY-RUNNINGMEAN_V5/2021/245/SMAP_L3_SSS_20210906_8DAYS_V5.0.nc'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/s3#',
#     'title': 'This link provides direct download access via S3 to the granule',
#     'hreflang': 'en-US',
#     'href': 's3://podaac-ops-cumulus-protected/SMAP_JPL_L3_SSS_CAP_8DAY-RUNNINGMEAN_V5/2021/245/SMAP_L3_SSS_20210906_8DAYS_V5.0.nc'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'title': 'api endpoint to retrieve temporary credentials valid for same-region direct s3 access',
#     'hreflang': 'en-US',
#     'href': 'https://archive.podaac.earthdata.nasa.gov/s3credentials'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/service#',
#     'title': 'OPeNDAP request URL',
#     'hreflang': 'en-US',
#     'href': 'https://opendap.earthdata.nasa.gov/collections/C2208422957-POCLOUD/granules/SMAP_L3_SSS_20210906_8DAYS_V5.0'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://github.com/podaac/data-readers'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://podaac-tools.jpl.nasa.gov/drive/files/allData/smap/docs/%20JPL-CAP_V5/'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'http://podaac.jpl.nasa.gov/smap'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'http://smap.jpl.nasa.gov/'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://podaac-tools.jpl.nasa.gov/drive/files/allData/smap/docs/%20JPL-CAP_V5/SMAP-SSS_JPL_V5.0_Documentation.pdf'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://podaac-tools.jpl.nasa.gov/drive/files/allData/smap/README.KnownIssues.txt'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://podaac.jpl.nasa.gov/CitingPODAAC'},
#    {'inherited': True,
#     'length': '0.0MB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'https://cmr.earthdata.nasa.gov/virtual-directory/collections/C2208422957-POCLOUD'},
#    {'inherited': True,
#     'length': '0.0MB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'https://search.earthdata.nasa.gov/search/granules?p=C2208422957-POCLOUD'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'hreflang': 'en-US',
#     'href': 'https://github.com/podaac/data-subscriber'}]}]

# %%
# ---- DOWNLOAD DATA ----
# create a local folder for the data if it doesn't exist
savedir = f'{datadir}smap/L3/'
os.makedirs(savedir, exist_ok=True)

# download the granules
granules = response.json()['feed']['entry']

# convert our start/end dates to datetime format:
start_date_dt = datetime.strptime(start_date,'%Y-%m-%dT%H:%M:%S').date()
end_date_dt = datetime.strptime(end_date,'%Y-%m-%dT%H:%M:%S').date() 
# list of granules we will download and load:
granules_load = []
for granule in granules:
    url = granule['links'][0]['href']
    id = granule['title'] + '.nc'
    r = requests.get(url)
    outfile = Path(savedir, id)
    # convert time_start from the file metadata to a datetime:
    thistime =  datetime.strptime(granule['time_start'],'%Y-%m-%dT%H:%M:%S.000Z').date() 
    # note! these are 8-day running means, so the search returns 9 files per day
    # only bother loading the days of interest (there's probably a nicer way to to this!)
    # - check if the granule if it is between start_date and end_date
    if (thistime >= start_date_dt) & (thistime <= end_date_dt):
        print(thistime, id)
        granules_load.append(f'{savedir}/{id}')
        # if the file doens't exist locally, download
        if (not outfile.exists()):
            print('downloading', url, id)
            with open(outfile, 'wb') as f:
                f.write(r.content)    
        else:
            print('already exists - skipping')
else:
    print(granule['title'] + ' out of time range, not downloading')
# Out:
# 2021-09-01 SMAP_L3_SSS_20210905_8DAYS_V5.0.nc
# already exists - skipping
# 2021-09-02 SMAP_L3_SSS_20210906_8DAYS_V5.0.nc
# already exists - skipping
# SMAP_L3_SSS_20210906_8DAYS_V5.0 out of time range, not downloading
