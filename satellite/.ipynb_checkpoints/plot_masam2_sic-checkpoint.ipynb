# %% [markdown]
# plot SIC from the MASAM2: Daily 4 km Arctic Sea Ice Concentration, Version 1 data set.
#
# data can be accessed from: ftp://sidads.colorado.edu/pub/DATASETS/NOAA/G10005/
#
# Please refer to the following data set web page for documentation and citation information:
# https://nsidc.org/data/g10005
#
# k.drushka // feb 2022

# %%
import sys
import xarray as xr
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.ticker as mticker

import glob
import numpy as np
import nctoolkit as nc

import cartopy
# Out:
# nctoolkit is using Climate Data Operators version 1.9.9

# %%
ddir = '/data1/sassie/satellite/seaice/masam2/'
files = glob.glob(ddir + "*nc")

# %%
ds = xr.open_mfdataset(files)
ds
# Out:
# <xarray.Dataset>
# Dimensions:                (t: 28, x: 2100, y: 2550)
# Dimensions without coordinates: t, x, y
# Data variables:
#     Longitude              (y, x) float32 dask.array<chunksize=(2550, 2100), meta=np.ndarray>
#     Latitude               (y, x) float32 dask.array<chunksize=(2550, 2100), meta=np.ndarray>
#     Day_of_Month           (t) int32 dask.array<chunksize=(28,), meta=np.ndarray>
#     Sea_Ice_Concentration  (t, y, x) int8 dask.array<chunksize=(28, 2550, 2100), meta=np.ndarray>

# %%
# convert with nctoolkit? no... doesn't work.

# thisf = files[0]
# data = nc.open_data(thisf)
## data.rename({'Day_of_Month':'t', 'Longitude':'x', 'Latitude':'y'})
# data.rename({'Day_of_Month':'t'})
# # data
# # convert to lat/lon
# data.to_latlon(lon=[-180, 180], lat=[30, 90], res=0.1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/miniconda3/envs/py33/lib/python3.9/site-packages/nctoolkit/regrid.py in regrid(self, grid, method, recycle)
#     132         try:
# --> 133             weights_nc = run_cdo(cdo_command, target=weights_nc)
#     134         except Exception as e:
#
# ~/miniconda3/envs/py33/lib/python3.9/site-packages/nctoolkit/runthis.py in run_cdo(command, target, out_file, overwrite)
#     322                     remove_safe(start_target)
# --> 323                     raise ValueError(
#     324                         str(result1)
#
# ValueError: Error (cdf_get_var1_double): NetCDF: HDF errorcdf_get_var1_double: ncid = 65536 varid = 0
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-8fb03972915a> in <module>
#       4 # data
#       5 # convert to lat/lon
# ----> 6 data.to_latlon(lon=[-180, 180], lat=[30, 90], res=0.1)
#       7
#
# ~/miniconda3/envs/py33/lib/python3.9/site-packages/nctoolkit/to_lonlat.py in to_latlon(self, lon, lat, res, method, recycle)
#     117
#     118     # call regrid
# --> 119     self.regrid(grid=grid_file, method=method, recycle = recycle)
#     120
#     121     remove_safe(grid_file)
#
# ~/miniconda3/envs/py33/lib/python3.9/site-packages/nctoolkit/regrid.py in regrid(self, grid, method, recycle)
#     135             del tracker
#     136             remove_safe(weights_nc)
# --> 137             raise ValueError(e)
#     138
#     139         if recycle:
#
# ValueError: Error (cdf_get_var1_double): NetCDF: HDF errorcdf_get_var1_double: ncid = 65536 varid = 0

# %%
data
# Out:
# <nctoolkit.DataSet>:
# Files: 1 member ensemble
# Variables: 0,65536,=,cdf_get_var1_double:,ncid,varid

# %%
ds.Sea_Ice_Concentration.isel(t=-3).plot()

# %%
# index of time to plot
ti = 1

fig, ax1 = plt.subplots(1,1, 
        subplot_kw={'projection': ccrs.NorthPolarStereo(central_longitude=-150)}, 
        figsize=(6,6))

pc = ax1.pcolormesh(ds.Longitude, ds.Latitude, ds.Sea_Ice_Concentration.isel(t=ti),
                   transform=ccrs.PlateCarree())

# #  ----- map stuff
# ax1.coastlines(color='none')  # coastline
# ax1.set_extent([-170, -130,68, 80], crs=ccrs.PlateCarree())
# gl = ax1.gridlines(draw_labels=True, dms=True, x_inline=False, y_inline=False, alpha=0.3)
# # ax1.set_title()
# plt.colorbar(pc, ax=ax1, orientation="horizontal", pad=0.05).set_label('SIC')
# # land color
# ax1.add_feature(cartopy.feature.LAND , facecolor=(.7,.7,.7))
# # ticks
# gl.ylocator = mticker.FixedLocator([68, 70, 72, 74, 76, 78])
# gl.xlocator = mticker.FixedLocator([-170, -160, -150, -140, -130])
# gl.top_labels = False
# gl.bottom_labels = True

# %%
plt.plot(ds.Longitude, ds.Latitude, '.')
plt.show()
